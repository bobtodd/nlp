# %% [markdown]
# # Latin Vocabulary from the Bridge

# %% [markdown]
# I found some Latin & Greek vocabulary tools hosted at [The Bridge](http://bridge.haverford.edu/), a project hosted by Haverford College.  In particular, you can select from a range of texts (not only classical texts like Vergil's *Aeneid*, but also textbooks like Moreland & Fleisher's *Latin: an Intensive Course*) and download the vocabulary as a TSV or Excel file.  Since the TSV files don't seem to include column headers, I think I'll work with Excel files for now.

# %% [markdown]
# The files are in principle set up directly for import into flashcard programs like Anki (they actually mention this specifically), but only for naive import.  Specifically, all forms for a single vocabulary entry (e.g. all principal parts for a given verb) are a single string in a single column.  If your Anki cards have separate data cells for each principal part, say, then the data format won't work as it stands.  So this notebook is going to start by separating individual data elements from one another for easier manipulation.

# %%
import pandas as pd
#import numpy as np
#import math
#import re
#import subprocess
#import os
#import string
#from nltk.corpus import stopwords

# %% [markdown]
# Since the data is in an Excel file (we could use a TSV file, but that doesn't come with column names), you'll need to make sure you've installed `xlrd`:
# ```
# > pyenv activate nlp3 # an environment with Python 3.x and pandas
# > pip install xlrd
# ```
# Make sure to re-import `pandas` in the above setup box so that it picks up on the dependency.

# %%
#xl = pd.ExcelFile("data/dcc_core_latin_vocabulary_bridge20150730_all.xls")

# %%
#xl.sheet_names

# %%
#df = xl.parse("Sheet1")

# %% [markdown]
# As it turns out, trying to read the data file as a true Excel file gives an error.  It's similar to what you find in [this thread about unsupported formats in `xlrd`](http://stackoverflow.com/questions/9623029/python-xlrd-unsupported-format-or-corrupt-file).  According to that thread, and also with a look [here](http://stackoverflow.com/questions/28710618/pandas-read-html-equivalent-for-a-lxml-table), the thing to do is install the dependency `lxml` and use the `pandas` function `read_html()`.  So make sure you do
# ```
# > pyenv activate nlp3
# > pip install lxml
# ```
# and then proceed as follows.

# %%
xl = pd.read_html("data/dcc_core_latin_vocabulary_bridge20150730_all.xls")

# %%
xl[:5]
# Out:
# [                            Dictionary Entry Part of Speech  \
#  0                  abeÅ abÄ«re abiÄ« abitum           Verb
#  1             absum abesse ÄfuÄ« ÄfutÅ«rus           Verb
#  2                                         ac    Conjunction
#  3       accÄdÅ accÄdere accessÄ« accessum           Verb
#  4         accidÅ accidere accidÄ« âââ           Verb
#  5        accipiÅ accipere accÄpÄ« acceptus           Verb
#  6                         Äcer Äcris Äcre      Adjective
#  7                          aciÄs aciÄÄ« f.           Noun
#  8                                         ad    Preposition
#  9               addÅ addere addidÄ« additus           Verb
#  10       addÅ«cÅ adducere addÅ«xÄ« adductus           Verb
#  11         adeÅ adÄ«re adÄ«vÄ«/adiÄ« aditus           Verb
#  12                                     adeÅ         Adverb
#  13     adhibeÅ adhibÄre adhibuÄ« adhibitus           Verb
#  14                                    adhÅ«c         Adverb
#  15      adveniÅ advenÄ«re advÄnÄ« adventus           Verb
#  16                       adversus âa âum      Adjective
#  17                                  adversus         Adverb
#  18      advertÅ advertere advertÄ« adversum           Verb
#  19                           aedÄs aedis f.           Noun
#  20                        aeger aegra aegrum      Adjective
#  21                                    aegrÄ         Adverb
#  22                                    aequÄ         Adverb
#  23                        aequor aequoris n.           Noun
#  24                         aequus âa âum      Adjective
#  25                           ÄÄr Äeris m.           Noun
#  26                              aes aeris n.           Noun
#  27                        aetÄs aetÄtis f.           Noun
#  28                       aeternus âa âum      Adjective
#  29                       aethÄr aetheris n.           Noun
#  ..                                       ...            ...
#  968  ulterior âor âus ultimus âa âum      Adjective
#  969                                   ultrÄ    Preposition
#  970                          umbra umbrae f.           Noun
#  971                                   umquam         Adverb
#  972                            unda undae f.           Noun
#  973                                     unde         Adverb
#  974                                  undique         Adverb
#  975                         Å«nus âa âum         Number
#  976          vocÅ vocÄre vocÄvÄ« vocÄtus           Verb
#  977                       volÅ velle voluÄ«           Verb
#  978                 volucer volucris volucre      Adjective
#  979               volucris volucris m. or f.           Noun
#  980                 voluntÄs voluntÄtis f.           Noun
#  981                 voluptÄs voluptÄtis f.           Noun
#  982                     vÅs vestrum/vestrÄ«        Pronoun
#  983                         vÅtum vÅtÄ« n.           Noun
#  984                           vÅx vÅcis f.           Noun
#  985                            urbs urbis f.           Noun
#  986                                   Å«sque         Adverb
#  987                          Å«sus Å«sÅ«s m.           Noun
#  988                                       ut    Conjunction
#  989                 uterque utraque utrumque        Pronoun
#  990                   Å«tilis Å«tilis Å«tile      Adjective
#  991                    Å«tor Å«tÄ« Å«sus sum           Verb
#  992                                    utrum         Adverb
#  993                                   vulgÅ         Adverb
#  994                         vulgus vulgÄ« n.           Noun
#  995                       vulnus vulneris n.           Noun
#  996                        vultus vultÅ«s m.           Noun
#  997                          uxor uxÅris f.           Noun
#
#                                Basic English Definition  \
#  0                                           to go away
#  1                              "to be away, be absent"
#  2                                      and in addition
#  3                                          to approach
#  4                                      to fall; happen
#  5                                           to receive
#  6                                    "sharp, piercing"
#  7                                 edge; line of battle
#  8                                 "to, up to, towards"
#  9                                           to give to
#  10                                "to lead to, induce"
#  11                                            to go to
#  12                                 "such a degree, so"
#  13                                            to apply
#  14                           "thus far, to this point"
#  15                                           to arrive
#  16                          opposed; opposite; towards
#  17   "facing, opposite, against, opposed (to) (adv....
#  18                                     to turn towards
#  19                                            building
#  20                                                sick
#  21                                     with difficulty
#  22                                             equally
#  23                           level surface; sea; plain
#  24                                               equal
#  25                                                 air
#  26                                    "copper, bronze"
#  27                                                 age
#  28                              "everlasting, eternal"
#  29                                           upper air
#  ..                                                 ...
#  968                                            farther
#  969                      beyond (adv. and prep. +acc.)
#  970                                             shadow
#  971                                               ever
#  972                                               wave
#  973                                             whence
#  974                                     from all sides
#  975                                                  1
#  976                                            to call
#  977                                            to wish
#  978                                             flying
#  979                                               bird
#  980                                             desire
#  981                                           pleasure
#  982                                                you
#  983                                                vow
#  984                                              voice
#  985                                               city
#  986                                       continuously
#  987                                                use
#  988             "as, when; that; how? In what manner?"
#  989                                        each of two
#  990                                             useful
#  991                                             to use
#  992  introduces the first question of a double dire...
#  993                                           commonly
#  994                                      common people
#  995                                              wound
#  996                                         expression
#  997                                               wife
#
#                                 Full English Definition  Conjugation  \
#  0                                           to go away            5
#  1                           "to be absent, be distant"            5
#  2    "and in addition, or and besides; and, as well...          NaN
#  3                 "to go or come to, approach; happen"            3
#  4                            "to fall, befall, happen"            3
#  5          "to receive; accept; hear (of), learn (of)"            3
#  6                                "sharp, keen; fierce"          NaN
#  7                     sharp edge; keennes; battle line          NaN
#  8            "toward, to; for the purpose of (+ acc.)"          NaN
#  9    "to add, insert, bring/attach to, say in addit...            3
#  10   "to lead up/to/away; bring up/to; persuade, in...            3
#  11   "to approach; attack; visit, address; undertak...            5
#  12   "such a point; precisely, exactly; thus far; i...          NaN
#  13   "to summon, invite, bring in; consult; put, ad...            2
#  14   "thus far, till now, to this point; hitherto; ...          NaN
#  15                                           to arrive            4
#  16   "towards, opposite, directly facing; opposed, ...          NaN
#  17           "facing, opposite, against, opposed (to)"          NaN
#  18                                     to turn towards            3
#  19   "temple, shrine; tomb; apartment, room; house ...          NaN
#  20                                         "sick, ill"          NaN
#  21   "scarcely, with difficulty, painfully, hardly;...          NaN
#  22   "equally, justly, fairly; in same/like manner/...          NaN
#  23                           level surface; sea; plain          NaN
#  24      "level, even; equitable, just; calm, tranquil"          NaN
#  25   "air (one of 4 elements); atmosphere, sky; clo...          NaN
#  26   "money, pay, fee, fare; copper/bronze/brass, b...          NaN
#  27                                 age; lifetime; time          NaN
#  28                              "everlasting, eternal"          NaN
#  29                "pure upper air, ether, heaven, sky"          NaN
#  ..                                                 ...          ...
#  968  "far; farther; farthest, latest; last; highest...          NaN
#  969           "beyond, further (adv. and prep. +acc.)"          NaN
#  970                                    "shadow, shade"          NaN
#  971                                               ever          NaN
#  972                                               wave          NaN
#  973                               "from where, whence"          NaN
#  974  "from every side/direction/place/part/source; ...          NaN
#  975                                                  1          NaN
#  976                              to call; summon; name            1
#  977                        "to be willing, want, wish"            5
#  978                                             flying          NaN
#  979                                               bird          NaN
#  980  "will, desire; purpose; good will; wish, favor...          NaN
#  981                              "pleasure, enjoyment"          NaN
#  982                                                you          NaN
#  983                        "solemn promise, vow; hope"          NaN
#  984                                        voice; word          NaN
#  985                                               city          NaN
#  986  "all the way, right on; all the time, continuo...          NaN
#  987  "use, enjoyment; experience, skill, advantage;...          NaN
#  988  "as; when; (introduces Purpose clause, in orde...          NaN
#  989  "which (of two), whichever, no matter which; o...          NaN
#  990  "useful, profitable, practical, helpful, advan...          NaN
#  991               "to use; experience, enjoy (+ abl.)"            3
#  992  introduces the first question of a double dire...          NaN
#  993                                           commonly          NaN
#  994  common people/general public/multitude/common ...          NaN
#  995                                              wound          NaN
#  996                                   expression; face          NaN
#  997  "wife; [uxorem ducere => marry, bring home as ...          NaN
#
#       Declension  Numbers  Proper Nouns/Adjs  Reg Adj/Adv
#  0           NaN      NaN                NaN          NaN
#  1           NaN      NaN                NaN          NaN
#  2           NaN      NaN                NaN          NaN
#  3           NaN      NaN                NaN          NaN
#  4           NaN      NaN                NaN          NaN
#  5           NaN      NaN                NaN          NaN
#  6             3      NaN                NaN          NaN
#  7             5      NaN                NaN          NaN
#  8           NaN      NaN                NaN          NaN
#  9           NaN      NaN                NaN          NaN
#  10          NaN      NaN                NaN          NaN
#  11          NaN      NaN                NaN          NaN
#  12          NaN      NaN                NaN          NaN
#  13          NaN      NaN                NaN          NaN
#  14          NaN      NaN                NaN          NaN
#  15          NaN      NaN                NaN          NaN
#  16            1      NaN                NaN          NaN
#  17          NaN      NaN                NaN          NaN
#  18          NaN      NaN                NaN          NaN
#  19            3      NaN                NaN          NaN
#  20            1      NaN                NaN          NaN
#  21          NaN      NaN                NaN            1
#  22          NaN      NaN                NaN            1
#  23            3      NaN                NaN          NaN
#  24            1      NaN                NaN          NaN
#  25            3      NaN                NaN          NaN
#  26            3      NaN                NaN          NaN
#  27            3      NaN                NaN          NaN
#  28            1      NaN                NaN          NaN
#  29            3      NaN                NaN          NaN
#  ..          ...      ...                ...          ...
#  968           3      NaN                NaN          NaN
#  969         NaN      NaN                NaN          NaN
#  970           1      NaN                NaN          NaN
#  971         NaN      NaN                NaN          NaN
#  972           1      NaN                NaN          NaN
#  973         NaN      NaN                NaN          NaN
#  974         NaN      NaN                NaN          NaN
#  975         NaN        1                NaN          NaN
#  976         NaN      NaN                NaN          NaN
#  977         NaN      NaN                NaN          NaN
#  978           3      NaN                NaN          NaN
#  979           3      NaN                NaN          NaN
#  980           3      NaN                NaN          NaN
#  981           3      NaN                NaN          NaN
#  982         NaN      NaN                NaN          NaN
#  983           2      NaN                NaN          NaN
#  984           3      NaN                NaN          NaN
#  985           3      NaN                NaN          NaN
#  986         NaN      NaN                NaN          NaN
#  987           4      NaN                NaN          NaN
#  988         NaN      NaN                NaN          NaN
#  989         NaN      NaN                NaN          NaN
#  990           3      NaN                NaN          NaN
#  991         NaN      NaN                NaN          NaN
#  992         NaN      NaN                NaN          NaN
#  993         NaN      NaN                NaN          NaN
#  994           2      NaN                NaN          NaN
#  995           3      NaN                NaN          NaN
#  996           4      NaN                NaN          NaN
#  997           3      NaN                NaN          NaN
#
#  [998 rows x 9 columns]]
