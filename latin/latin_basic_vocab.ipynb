# %% [markdown]
# # Basic Vocabulary for Latin

# %% [markdown]
# The first task here is going to be to take *Paul B. Diederich's Basic Vocabulary* as found on [Carolus Raeticus's page](http://hiberna-cr.wikidot.com/downloads) and convert it into a `.tsv` file suitable for import into the [Anki](http://ankisrs.net/) flashcard program.

# %% [markdown]
# There are a few things to keep in mind.  First, we need to separate verbs from the remaining vocabulary.  This is because I treat verbs differently: they have principal parts, which come in varying numbers.  By contrast nouns and adjectives can fit into a more general "vocabulary" type, generally defined by three forms (nominative & genitive singular, plus nominative plural, for nouns vs. nominative singular for three genders for adjectives).

# %% [markdown]
# ## Setup

# %% [markdown]
# Let's first load some data-manipulation packages and get the raw data loaded into memory.

# %%
import pandas as pd
import os

# %%
homedir   = os.path.expanduser("~")
curdir    = os.curdir
datadir   = curdir + '/' + 'data'
tmpdir    = curdir + '/' + 'tmp'
rawfile   = 'diederich_lodge_practice_raeticus20121219_macrons.txt'
outfile   = 'basic_vocabulary.tsv'
rawdata   = datadir + '/' + rawfile
saveddata = datadir + '/' + outfile

# %%
rawdf = pd.read_csv(rawdata, sep='\t', skiprows=79)

# %%
rawdf.head(20)
# Out:
#    Struct   d.  Sect.  Sub-Sect.                         Latin  \
# 0       x  NaN      1          1                  deus, -ī, m.
# 1      xx  NaN      1          1                  dea, -ae, f.
# 2      xx  NaN      1          1              dīvīnus, -a, -um
# 3      xx  NaN      1          1                dīvus, -a, -um
# 4      xx   d.      1          1                  dīves, -itis
# 5       x  NaN      1          1               nympha, -ae, f.
# 6       x  NaN      1          1            religiō, -ōnis, f.
# 7       x  NaN      1          1               templum, -ī, n.
# 8       x  NaN      1          1                  āra, -ae, f.
# 9       x  NaN      1          1               vātēs, -is, mf.
# 10      x  NaN      1          1                 vōtum, -ī, n.
# 11     xx  NaN      1          1  dēvoveō, -ēre, -vōvī, -vōtum
# 12      x  NaN      1          1              nūmen, -inis, n.
# 13      x  NaN      1          1                 fātum, -ī, n.
# 14     xx  NaN      1          1              fortūna, -ae, f.
# 15     xx  NaN      1          1              sors, sortis, f.
# 16      x  NaN      1          2             tempus, -oris, n.
# 17      x  NaN      1          2              aetās, -ātis, f.
# 18     xx  NaN      1          2                 aevum, -ī, n.
# 19     xx  NaN      1          2              saeculum, -ī, n.
#
#                                       English (Lodge)
# 0                                                 god
# 1                                             goddess
# 2                           divine, godlike, inspired
# 3                divine, godlike; (noun) god, goddess
# 4                                                rich
# 5                                               nymph
# 6   conscientiousness, sense of right; scruples; (...
# 7   place marked off for augury; holy ground; shri...
# 8                                               altar
# 9                     prophet, soothsayer, seer, bard
# 10  solemn promise (made to some deity), vow; a th...
# 11                       to set apart by vows, devote
# 12                          divine help, glory; deity
# 13                   fate (lit. that which is spoken)
# 14                                            fortune
# 15                lot; fate, destiny, oracle, success
# 16  I. limited duration of time; time in all sense...
# 17                                  age, time of life
# 18         lifetime, age, old age (properly eternity)
# 19   a generation; age, esp. century; time in general

# %% [markdown]
# Looking at the output, we need to split the "Latin" column into pieces, primarily splitting on the commas.  The problem is that sometimes we have nouns, sometimes adjectives, sometimes verbs.  And even within these we might get a varying number of elements to split (e.g. 1st/2nd declension adjectives vs. 3rd declension, or regular vs. deponent verbs, etc.).

# %%
rawdf.tail()
# Out:
#      Struct   d.  Sect.  Sub-Sect.               Latin  \
# 1513     xx  NaN      8          1  postrēmus, -a, -um
# 1514      x  NaN      8          1         con- (com-)
# 1515      x  NaN      8          1                dis-
# 1516      x  NaN      8          1          re- (red-)
# 1517      x  NaN      8          1       trāns- (trā-)
#
#                                         English (Lodge)
# 1513  hindmost, the last; end or last part of any th...
# 1514                                  (prefix) together
# 1515                                (prefix) apart, not
# 1516                               (prefix) back, again
# 1517                                    (prefix) across
